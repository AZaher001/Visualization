# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize': [10, 10]}, font_scale=1.3)

# %%
df = pd.read_csv('911.csv')
df
# Out:
#               lat        lng  \
# 0       40.297876 -75.581294
# 1       40.258061 -75.264680
# 2       40.121182 -75.351975
# 3       40.116153 -75.343513
# 4       40.251492 -75.603350
# ...           ...        ...
# 115206  40.265484 -75.293554
# 115207  40.131681 -75.389806
# 115208  40.186753 -75.143373
# 115209  40.155928 -75.141169
# 115210  40.147850 -75.333684
#
#                                                      desc      zip  \
# 0       REINDEER CT & DEAD END;  NEW HANOVER; Station ...  19525.0
# 1       BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...  19446.0
# 2       HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...  19401.0
# 3       AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...  19401.0
# 4       CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...      NaN
# ...                                                   ...      ...
# 115206  WERNER RD & ORVILLA RD;  HATFIELD TOWNSHIP; St...  19440.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115211 entries, 0 to 115210
# Data columns (total 14 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   lat          115211 non-null  float64
#  1   lng          115211 non-null  float64
#  2   desc         115211 non-null  object
#  3   zip          100789 non-null  float64
#  4   title        115211 non-null  object
#  5   timeStamp    115211 non-null  object
#  6   twp          115177 non-null  object
#  7   addr         115211 non-null  object
#  8   e            115211 non-null  int64
#  9   Reason       115211 non-null  object
#  10  hour         115211 non-null  int64
#  11  month        115211 non-null  int64
#  12  day of week  115211 non-null  object
#  13  Year         115211 non-null  int64
# dtypes: float64(3), int64(4), object(7)
# memory usage: 12.3+ MB

# %%
df.describe()
# Out:
#                  lat            lng            zip         e           hour  \
# count  115211.000000  115211.000000  100789.000000  115211.0  115211.000000
# mean       40.159127     -75.317145   19237.423201       1.0      13.064759
# std         0.093297       0.170770     336.415922       0.0       5.662017
# min        30.333596     -95.595595   17752.000000       1.0       0.000000
# 25%        40.100234     -75.391998   19038.000000       1.0       9.000000
# 50%        40.144526     -75.304780   19401.000000       1.0      13.000000
# 75%        40.229008     -75.211866   19446.000000       1.0      17.000000
# max        41.167156     -74.995041   77316.000000       1.0      23.000000
#
#                month           Year
# count  115211.000000  115211.000000
# mean        5.539714    2015.931291
# std         3.115296       0.252959
# min         1.000000    2015.000000
# 25%         3.000000    2016.000000
# 50%         5.000000    2016.000000
# ...

# %%
sns.displot(df['hour'] ,color = 'b' ,bins = 30 ,aspect = 1.5)

# %%
sns.kdeplot(df['hour'] ,color = 'b' , shade = True)
# Out:
# <AxesSubplot:xlabel='hour', ylabel='Density'>

# %% [markdown]
# * average count  of hours (12 : 17) hour

# %%
sns.displot(df['month'] ,color = 'r' ,aspect = 2 ,bins = 30)

# %%
sns.kdeplot(df['month'] ,color = 'b' , shade = True)
# Out:
# <AxesSubplot:xlabel='month', ylabel='Density'>

# %% [markdown]
# * average count of people that work one month are large
# * average count of people that work  12 month are least
# * most people work  (2:9) months
# * Fewer people came in month 10
# * no one worked 11 month

# %%
sns.displot(df['Year'] ,color = 'g' ,aspect = 2 ,bins = 30)

# %%
sns.kdeplot(df['Year'] ,color = 'g' ,shade = True)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Density'>

# %% [markdown]
# * Most of the people working in the job in 2016

# %%
sns.jointplot(data=df ,x='month', y='hour' ,kind='reg' )

# %% [markdown]
# * month increase , average hour fixed at (10 : 15)hour
# * average hours job for 12 month  (10 : 15) hour
# * average people who worked more hours , have been existed for more than 4 months

# %%
sns.jointplot(data=df ,x='month', y='Year' ,kind='scatter' )

# %% [markdown]
# * people that work (2: 10) months are came in 2016 but people who come in 2015 worked 12 month
# * people that came 2016 are more than who came 2015

# %%
sns.pairplot(data=df )

# %%
fig,axes = plt.subplots(figsize=(16,10))
sns.countplot(data=df , x='twp')
plt.xticks(rotation=90)
plt.tight_layout()

# %% [markdown]
# * the most count from Lower Merion

# %%
sns.countplot(data=df , x='Reason')
# Out:
# <AxesSubplot:xlabel='Reason', ylabel='count'>

# %% [markdown]
# * count of people that came for EMS Reason are the most but who came for Fire Reason are the least

# %%
fig,axes=plt.subplots(figsize=(18,10))
sns.countplot(data=df , x='day of week' ,hue = 'Reason')
# Out:
# <AxesSubplot:xlabel='day of week', ylabel='count'>

# %% [markdown]
# * Most of the week ,people come naturally as the numbers diverged
# * but on saterday and sunday , people came less , especially sunday
# * most people that come for EMS Reason , least for ( Fire Reason )
# * the most people that come for EMS Reason , come friday
# * average count of people that come for Traffic , come nuturally during the week but less day (sun day)
# * average count of people that come for Fire Reason ,  come nuturally during the week

# %%
fig,axes=plt.subplots(figsize=(18,10))
sns.stripplot(data=df , x='twp' , y='Reason')
plt.xticks(rotation=90)
plt.tight_layout()

# %%
fig,axes=plt.subplots(figsize=(18,10))
sns.stripplot(data=df , x='twp' , y='day of week')
plt.xticks(rotation=90)
plt.tight_layout()

# %%
fig,axes=plt.subplots(figsize=(18,10))
sns.boxplot(data=df , x='twp' , y='hour')
plt.xticks(rotation=90)
plt.tight_layout()

# %%
fig,axes=plt.subplots(figsize=(18,10))
sns.violinplot(data=df , x='twp' , y='hour')
plt.xticks(rotation=90)
plt.tight_layout()

# %% [markdown]
# * most hours  that people spend it in Lehigh couinty (8h : 20h)

# %%
fig,axes=plt.subplots(figsize=(18,10))
sns.boxplot(data=df , x='twp' , y='month')
plt.xticks(rotation=90)
plt.tight_layout()

# %% [markdown]
# * average months (3:8)

# %%
fig,axes=plt.subplots(figsize=(18,10))
sns.barplot(data=df , x='twp' , y='month')
plt.xticks(rotation=90)
plt.tight_layout()

# %%
fig,axes=plt.subplots(figsize=(18,10))
sns.barplot(data=df , x='twp' , y='Year')
plt.xticks(rotation=90)
plt.tight_layout()

# %%
fig,axes=plt.subplots(figsize=(18,10))
sns.boxplot(data=df , x='Reason' , y='hour')
plt.xticks(rotation=90)
plt.tight_layout()

# %%
sns.violinplot(data=df , x='Reason' , y='hour')
# Out:
# <AxesSubplot:xlabel='Reason', ylabel='hour'>

# %%
sns.stripplot(data=df , x='Reason' , y='hour' )
# Out:
# <AxesSubplot:xlabel='Reason', ylabel='hour'>

# %%
sns.barplot(data=df , x='Reason' , y='hour')
# Out:
# <AxesSubplot:xlabel='Reason', ylabel='hour'>

# %% [markdown]
# * average hours of people that come for (EMS Reason) -- (form 0 to 5 ) hours , great than fire and traffic
# * average hours of people that come for (fire Reason) -- form 9 to 18
# * average hours of people that come for (fire Reason) -- form 9 to 17
# * people who spend more hours are fire reason

# %%
sns.boxplot(data=df , x='Reason' , y='month')
# Out:
# <AxesSubplot:xlabel='Reason', ylabel='month'>

# %%
sns.violinplot(data=df , x='Reason' , y='month')
# Out:
# <AxesSubplot:xlabel='Reason', ylabel='month'>

# %% [markdown]
# - average months of EMS and fire and Trafic are 6

# %%
sns.barplot(data=df , x='Reason' , y='month')
# Out:
# <AxesSubplot:xlabel='Reason', ylabel='month'>

# %%
fig,axes=plt.subplots(figsize=(18,10))
sns.boxplot(data=df , x='Reason' , y='Year')
plt.xticks(rotation=90)
plt.tight_layout()

# %%
fig,axes=plt.subplots(figsize=(18,10))
sns.boxplot(data=df ,x='day of week' , y='Year' )
plt.xticks(rotation=90)
plt.tight_layout()

# %%
sns.boxplot(data=df , x='day of week' , y='month' , hue = 'Reason')
# Out:
# <AxesSubplot:xlabel='day of week', ylabel='month'>

# %%
sns.stripplot(data=df , x='day of week' , y='hour')
# Out:
# <AxesSubplot:xlabel='day of week', ylabel='hour'>

# %%
sns.barplot(data=df , x='day of week' , y='hour' , hue = 'Reason')
# Out:
# <AxesSubplot:xlabel='day of week', ylabel='hour'>

# %% [markdown]
# * Traffic and fire  Reason is the most average hour in day
