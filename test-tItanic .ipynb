# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize': [10, 10]}, font_scale=1.3)

# %%
df = pd.read_csv('titanic.csv')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.4+ KB

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
sns.displot(df['survived'],bins = 15 ,color = 'r')

# %%
sns.kdeplot(df['survived'],shade=True ,color = 'b')
# Out:
# <AxesSubplot:xlabel='survived', ylabel='Density'>

# %% [markdown]
# **alive  are the least

# %%
sns.distplot(df['age'],color = 'b')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %% [markdown]
# **The average age of people from 19 to 41 year

# %%
sns.distplot(df['fare'],color = 'b',bins = 30)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='fare', ylabel='Density'>

# %% [markdown]
# **It shows that the average fare is from 0 to 50 and  some people income for free

# %%
sns.jointplot(data = df ,x = 'survived' ,y = 'age' ,hue = 'sex')

# %% [markdown]
# **alive people are up to 61, most are women, and under 20 the most are men(child)
# **The ages of the not survived ranged from two to 78 years, mostly men.

# %%
sns.jointplot(data = df ,x = 'survived' ,y = 'fare' ,hue = 'sex')

# %% [markdown]
# **most men that paid fare are not survived , most women that paid fare are alive

# %%
sns.jointplot(data = df ,x = 'age' ,y = 'fare' ,hue = 'who')

# %% [markdown]
# average age(18:45)
# average fare (0$ : 50$)
# most people paid fare Less than 100$
# child paid fare range(1$ : 50$)

# %%
sns.jointplot(data = df ,x = 'age' ,y = 'alone' ,hue = 'who')

# %% [markdown]
# most child not alone , and most woman ,but most men are alone and  have lost all people who known them

# %%
sns.pairplot(df ,hue = 'sex')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
sns.countplot(data = df , x='survived',hue='sex')
# Out:
# <AxesSubplot:xlabel='survived', ylabel='count'>

# %% [markdown]
# most survived are women , most death are men in a large percent

# %%
sns.countplot(data = df , x='age',hue='sex')
# Out:
# <AxesSubplot:xlabel='age', ylabel='count'>

# %%
sns.countplot(data = df , x='class',hue='sex')
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %% [markdown]
# third class is the most in titanic and men most than women in third class
# second class is the least in ship
# men in all classes is most than women but in third class much more

# %%
sns.countplot(data = df , x='who',hue='sex')
# Out:
# <AxesSubplot:xlabel='who', ylabel='count'>

# %% [markdown]
# The count of adult men is the most
# girl child is more than  male child

# %%
sns.countplot(data = df , x='embark_town',hue='sex')
# Out:
# <AxesSubplot:xlabel='embark_town', ylabel='count'>

# %% [markdown]
#  people from southampton is the most in titanic , men from southampton is the most
# next , people from cherbourg and  men are most also .
# People from Queenstown are the fewest on the ship .

# %%
sns.countplot(data = df , x='alive',hue='who')
# Out:
# <AxesSubplot:xlabel='alive', ylabel='count'>

# %%
sns.countplot(data = df , x='alone',hue='who')
# Out:
# <AxesSubplot:xlabel='alone', ylabel='count'>

# %% [markdown]
# people who are alone , men are the most ,next women next child
# people arenot alone , women are the most ,next men , next child
# alone men more than not alone men
# alone women less than not alon women
# not alone child most than alone child

# %%
sns.boxplot(data = df ,x='survived' , y='age',hue = 'who')
# Out:
# <AxesSubplot:xlabel='survived', ylabel='age'>

# %%
sns.violinplot(data = df ,x='survived' , y='age',hue = 'who',)
# Out:
# <AxesSubplot:xlabel='survived', ylabel='age'>

# %%
sns.stripplot(data = df ,x='survived' , y='age',hue = 'sex', palette='mako')
# Out:
# <AxesSubplot:xlabel='survived', ylabel='age'>

# %%
sns.swarmplot(data = df ,x='survived' , y='age',hue = 'who')
# Out:
# <AxesSubplot:xlabel='survived', ylabel='age'>

# %%
sns.barplot(data = df ,x='survived' , y='age',hue = 'who')
# Out:
# <AxesSubplot:xlabel='survived', ylabel='age'>

# %% [markdown]
# average age(dead-men) are (21:41) , average age(dead-women) are (22:31)  but the count of women are least
# average age(dead-child) are (3 : 10)
# average age(alive-men) are (25 :40) but the count is least , average age(alive-women) are (18 : 42)  ,
# Although women more than men but average lifespan least
# average age(alive-child) are (2 : 8)
# most young child are alive but average lifespan (dead)  greater

# %%
sns.boxplot(data = df , x='survived',y='fare',hue = 'sex')
# Out:
# <AxesSubplot:xlabel='survived', ylabel='fare'>

# %%
sns.violinplot(data = df , x='survived',y='fare',hue = 'sex')
# Out:
# <AxesSubplot:xlabel='survived', ylabel='fare'>

# %%
sns.stripplot(data = df , x='survived',y='fare',hue = 'sex')
# Out:
# <AxesSubplot:xlabel='survived', ylabel='fare'>

# %%
sns.swarmplot(data = df , x='survived',y='fare',hue = 'sex')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 49.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 14.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='survived', ylabel='fare'>

# %%
sns.barplot(data = df , x='survived',y='fare',hue = 'sex')
# Out:
# <AxesSubplot:xlabel='survived', ylabel='fare'>

# %% [markdown]
# survived men are paid fare more then dead men
# survived women are paid fare more then dead women
# survived women are paid fare more then servived men
# dead people are paid fare (1 : 55)
# survived people are paid fare (1 : 170) , women paid more than men and mostly paid big fare
# Pay rate ( women) in bigger

# %%
sns.boxplot(data = df , x='sex',y='age',hue = 'who')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
sns.violinplot(data = df , x='sex',y='age',hue = 'who')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
sns.stripplot(data = df , x='sex',y='age',hue = 'who')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
sns.swarmplot(data = df , x='sex',y='age',hue = 'who')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
sns.barplot(data = df , x='sex',y='age',hue = 'who')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %% [markdown]
# Average lifespan for adult men (20 : 40 )
# Average lifespan for adult women (20 : 38 )
# Average lifespan for boys (2 : 9 )
# Average lifespan for girls (3 : 13 ) are bigger than boys
# count of male bigger than female

# %%
sns.boxplot(data = df , x='sex',y='fare',hue = 'who')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='fare'>

# %%
sns.violinplot(data = df , x='sex',y='fare',hue = 'who')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='fare'>

# %%
sns.stripplot(data = df , x='sex',y='fare',hue = 'who')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='fare'>

# %%
sns.swarmplot(data = df , x='sex',y='fare',hue = 'who')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 48.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 13.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='sex', ylabel='fare'>

# %% [markdown]
# women paid more than men
# boys paid more than girls
# average baoys paid greater than men
# female paid grater than men
# average fare for women greater than men

# %%
sns.barplot(data = df , x='sex',y='fare',hue = 'who')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='fare'>

# %%
sns.violinplot(data = df , x='sex',y='alone' ,hue = 'who')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='alone'>

# %%
sns.stripplot(data = df , x='sex',y='alone' ,hue ='who')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='alone'>

# %%
sns.swarmplot(data = df , x='sex',y='alone' ,hue ='who')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 85.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 72.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='sex', ylabel='alone'>

# %%
sns.barplot(data = df , x='sex',y='alone' ,hue ='who')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='alone'>

# %% [markdown]
# girls-not alone greater than boys-not alone
# girls-alone greater than boys- alone
#
# girls-not alone greater than girls-alone
# boys-not alone greater than boys-alone
#
# female-not alone greater than male-not alone
# female-not alone greater than female- alone
#
# male-alone more than male-not alone

# %%
sns.stripplot(data = df , x='embark_town',y='survived',hue = 'who')
# Out:
# <AxesSubplot:xlabel='embark_town', ylabel='survived'>

# %%
sns.barplot(data = df , x='embark_town',y='survived',hue = 'who')
# Out:
# <AxesSubplot:xlabel='embark_town', ylabel='survived'>

# %% [markdown]
# mean child of southampton survived
# mean chlid of cherbourg survived
# mean child of queenstwon not survived
# child more survived  in  cherbourg
#
# mean man of southampton not survived
# mean man of cherbourg not survived
# mean man of queenstwon not survived
#
# mean woman of southampton  survived
# mean woman of cherbourg  survived
# mean woman of queenstwon  survived
# woman more  survived than men in queenstwon

# %%
sns.boxplot(data = df , x='embark_town',y='age',hue = 'who')
# Out:
# <AxesSubplot:xlabel='embark_town', ylabel='age'>

# %%
sns.violinplot(data = df , x='embark_town',y='age',hue = 'who')
# Out:
# <AxesSubplot:xlabel='embark_town', ylabel='age'>

# %%
sns.swarmplot(data = df , x='embark_town',y='age',hue = 'who')
# Out:
# <AxesSubplot:xlabel='embark_town', ylabel='age'>

# %%
sns.barplot(data = df , x='embark_town',y='age',hue = 'who')
# Out:
# <AxesSubplot:xlabel='embark_town', ylabel='age'>

# %% [markdown]
# average age(male and female) from  southampton (25:39)
# average age(child) from  southampton (2:8)
# **from  southampton , average men are the most
#
# average age(male) from  cherbourg (26:42)
# average age(female) from  cherbourg (22:45)
# average age(child) from  cherbourg (2:15)
# **from  cherbourg , average men are the most
#
#
# average age(male) from  queenstwon (28:48)
# average age(female) from  queenstwon (18:31)
# average age(child) from  queenstwon (3:7)
# **from  queenstwon , average men are the most
#
#
# average age(child) from  cherbourg are the greatest
# average age(women) from  cherbourg are the greatest
# average age(men) from  queenstwon are the greatest
#
# **The average age is similar in town , except queenstwon men have older ages and also have least
# count and the most count from southampton

# %%
sns.boxplot(data = df , x='embark_town',y='fare',hue ='who')
# Out:
# <AxesSubplot:xlabel='embark_town', ylabel='fare'>

# %%
sns.violinplot(data = df , x='embark_town',y='fare',hue ='who')
# Out:
# <AxesSubplot:xlabel='embark_town', ylabel='fare'>

# %%
sns.stripplot(data = df , x='embark_town',y='fare',hue ='who')
# Out:
# <AxesSubplot:xlabel='embark_town', ylabel='fare'>

# %%
sns.barplot(data = df , x='embark_town',y='fare',hue ='who')
# Out:
# <AxesSubplot:xlabel='embark_town', ylabel='fare'>

# %% [markdown]
# southampton is the most town paid fare  for child and average of men (2:21)  ,women and child (2 : 40)
# average fare (women,child) more than men at southampton
#
# cherbourg paid fare more other town  and average of men(2:55) , women (10:90) ,child(2:16)
# average  paid fare for women are bigger than men
# cherbourg is the most town paid fare for women and men
#
# queenstwon is the least town paid fare , and  child in the town paid more than men and women
# average child  fare (1:15) , men(1:10) ,women(1:11)

# %%
sns.stripplot(data = df , x='embark_town',y='alone',hue ='sex')
# Out:
# <AxesSubplot:xlabel='embark_town', ylabel='alone'>

# %%
sns.barplot(data = df , x='embark_town',y='alone',hue ='who')
# Out:
# <AxesSubplot:xlabel='embark_town', ylabel='alone'>

# %% [markdown]
# average alone people  more than not alone people
# average alone men in all town is very high
# most child not alone
#
# average men alone in southampton most not alone
#
# average not alone women in cherbourg more than alone
#
# average women alone in queenstwon more than not alone

# %%
sns.boxplot(data = df , x='class',y='alone')
# Out:
# <AxesSubplot:xlabel='class', ylabel='alone'>

# %%
sns.violinplot(data = df , x='class',y='alone' ,hue = 'sex')
# Out:
# <AxesSubplot:xlabel='class', ylabel='alone'>

# %% [markdown]
# men alone , the most in all class
# women not alone , the most
# not alone people in third class more than first and second

# %%
sns.swarmplot(data = df , x='class',y='alone',hue ='who')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 88.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 73.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 68.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='class', ylabel='alone'>

# %%
sns.barplot(data = df , x='class',y='alone',hue ='sex')
# Out:
# <AxesSubplot:xlabel='class', ylabel='alone'>

# %%
sns.boxplot(data = df , x='class',y='survived',hue ='who')
# Out:
# <AxesSubplot:xlabel='class', ylabel='survived'>

# %%
sns.violinplot(data = df , x='class',y='survived')
# Out:
# <AxesSubplot:xlabel='class', ylabel='survived'>

# %%
sns.swarmplot(data = df , x='class',y='survived',hue ='sex')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 88.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 73.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 68.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='class', ylabel='survived'>

# %%
sns.barplot(data = df , x='class',y='survived',hue ='sex')
# Out:
# <AxesSubplot:xlabel='class', ylabel='survived'>

# %% [markdown]
# women survived , the most in all class
# men not survived the most
# not survived people in third class moree than first and second
# survived in second class , the most women
# fist class men  survived , the most

# %%
sns.boxplot(data = df , x='class',y='age',hue ='sex')
# Out:
# <AxesSubplot:xlabel='class', ylabel='age'>

# %% [markdown]
# average ages of first class , the highest
# average ages of first class men , greater than women
# average ages of second class men and women

# %%
sns.violinplot(data = df , x='class',y='age',hue ='who')
# Out:
# <AxesSubplot:xlabel='class', ylabel='age'>

# %%
sns.stripplot(data = df , x='class',y='age',hue ='sex')
# Out:
# <AxesSubplot:xlabel='class', ylabel='age'>

# %%
sns.barplot(data = df , x='class',y='age',hue ='who')
# Out:
# <AxesSubplot:xlabel='class', ylabel='age'>

# %%
sns.boxplot(data = df , x='class',y='fare',hue ='who')
# Out:
# <AxesSubplot:xlabel='class', ylabel='fare'>

# %%
sns.violinplot(data = df , x='class',y='fare',hue ='who')
# Out:
# <AxesSubplot:xlabel='class', ylabel='fare'>

# %% [markdown]
# first class paid fare more than second and third
# child in first class paid most than men and women

# %%
sns.boxplot(data = df ,x='who' , y='age',hue = 'sex')
# Out:
# <AxesSubplot:xlabel='who', ylabel='age'>

# %%
sns.violinplot(data = df ,x='who' , y='age',hue = 'sex')
# Out:
# <AxesSubplot:xlabel='who', ylabel='age'>

# %%
sns.barplot(data = df ,x='who' , y='age',hue = 'sex')
# Out:
# <AxesSubplot:xlabel='who', ylabel='age'>

# %% [markdown]
# age of child - female  ,higher than male
# age of male greater than female

# %%
sns.stripplot(data = df , x='class',y='fare',hue ='who')
# Out:
# <AxesSubplot:xlabel='class', ylabel='fare'>

# %%
sns.barplot(data = df , x='class',y='fare',hue ='who')
# Out:
# <AxesSubplot:xlabel='class', ylabel='fare'>

# %%
sns.boxplot(data = df ,x='who' , y='fare',hue = 'sex')
# Out:
# <AxesSubplot:xlabel='who', ylabel='fare'>

# %%
sns.violinplot(data = df ,x='who' , y='fare',hue = 'sex',)
# Out:
# <AxesSubplot:xlabel='who', ylabel='fare'>

# %%
sns.stripplot(data = df ,x='who' , y='fare',hue = 'sex')
# Out:
# <AxesSubplot:xlabel='who', ylabel='fare'>

# %%
sns.barplot(data = df ,x='who' , y='fare',hue = 'sex')
# Out:
# <AxesSubplot:xlabel='who', ylabel='fare'>

# %% [markdown]
# women fare , the hightest
# child male-fare paid higher than female
# child paid fare higher than men

# %%
sns.boxplot(data = df ,x='alive' , y='fare',hue = 'who')
# Out:
# <AxesSubplot:xlabel='alive', ylabel='fare'>

# %%
sns.violinplot(data = df ,x='alive' , y='fare',hue = 'who')
# Out:
# <AxesSubplot:xlabel='alive', ylabel='fare'>

# %%
sns.stripplot(data = df ,x='alive' , y='fare',hue = 'who')
# Out:
# <AxesSubplot:xlabel='alive', ylabel='fare'>

# %%
sns.swarmplot(data = df ,x='alive' , y='fare',hue = 'who')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 49.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 14.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='alive', ylabel='fare'>

# %%
sns.barplot(data = df ,x='alive' , y='fare',hue = 'who')
# Out:
# <AxesSubplot:xlabel='alive', ylabel='fare'>

# %% [markdown]
# people who alive paid higher than dead
# men dead paid fare more than women dead
# women alive paid fare more than men alive
# child dead paid fare more than alive
# men alive paid more men dead

# %%
sns.swarmplot(data = df ,x='alive' , y='alone',hue = 'sex')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 84.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 74.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='alive', ylabel='alone'>

# %%
sns.barplot(data = df ,x='alive' , y='alone',hue = 'who')
# Out:
# <AxesSubplot:xlabel='alive', ylabel='alone'>

# %% [markdown]
# more men  are not alive
# more women are alive
# men alone-alive are more women

# %%
sns.stripplot(data = df , x='class',y='alive' ,hue = 'who')
# Out:
# <AxesSubplot:xlabel='class', ylabel='alive'>

# %%
sns.stripplot(data = df ,x='sex' , y='class',hue = 'sex')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='class'>

# %%
sns.swarmplot(data = df ,x='sex' , y='who',hue = 'sex')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 85.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 72.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='sex', ylabel='who'>
